# %%
import pandas as pd
df = pd.read_excel("../reports/final_business_dataset.xlsx")
print("Final Dataset Shape:", df.shape)
print("\nColumns:")
for col in df.columns:
    print(col)
# Out:
# Final Dataset Shape: (1383, 34)
#
# Columns:
# id_x
# company_id
# year
# sales
# expenses
# operating_profit
# opm_percentage
# other_income
# interest
# depreciation
# profit_before_tax
# tax_percentage
# net_profit
# eps
# dividend_payout
# id_y
# equity_capital
# reserves
# borrowings
# other_liabilities
# total_liabilities
# fixed_assets
# cwip
# investments
# other_asset
# total_assets
# id
# operating_activity
# investing_activity
# financing_activity
# net_cash_flow
# net_profit_margin
# debt_equity
# free_cash_flow

# %%
# %whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# col        str          free_cash_flow
# df         DataFrame    Shape: (1383, 34)
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
